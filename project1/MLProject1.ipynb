# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# !pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 42.7 MB 83 kB/s  eta 0:00:01     |██████████████▍                 | 19.3 MB 1.3 MB/s eta 0:00:18MB/s eta 0:00:13��████    | 37.4 MB 1.3 MB/s eta 0:00:04
# ...

# %%
pyarrow.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 pyarrow.__version__
#
# NameError: name 'pyarrow' is not defined

# %%
pyarrow -V
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 pyarrow -V
#
# NameError: name 'pyarrow' is not defined

# %%
python -V
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 python -V
#
# NameError: name 'python' is not defined

# %%
# !python -V
# Out:
# Python 3.9.12

# %%
# !pyarrow -V
# Out:
# /bin/bash: line 1: pyarrow: command not found

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'

# %%
import pyarrow

# %%
pyarrow.__version__
# Out:
# '21.0.0'
